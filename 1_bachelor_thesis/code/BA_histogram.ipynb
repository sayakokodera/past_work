# %% [markdown]
# # BA histogram for pos_scan and z_san error

# %%
import numpy as np
import matplotlib.pyplot as plt
from pint import UnitRegistry
ureg = UnitRegistry()
Q_ = ureg.Quantity

# %%
# settings
dx = 0.5 *ureg.millimetre
tS = 1/(80* 10**6)* ureg.second
c0 = 6300* ureg.metre / ureg.second
dz = 0.5* c0* tS
dz = dz.to('millimetre')

# %%
# settings for normal distribution
sigma_x = dx
sigma_z = dz
Nsample = 1600

# %%
# histogram for pos_scan
mu = 0
sigma = 5 # [mm]
dx_mgn = dx.magnitude
x = dx_mgn* np.random.normal(mu, sigma, Nsample)
count, bins, _ = plt.hist(x, 50, density = True)
plt.plot(bins, 
         1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
       linewidth=2, color='r')

# %%
n.max()
# Out:
# 92.0

# %%
new_x = 0.5* np.random.normal(0, sigma_x.magnitude, Nsample)
N = np.nonzero(abs(new_x) < 0.5)
len(N[0])/Nsample
# Out:
# 0.955625

# %%
gauss = 1/(sigma * np.sqrt(2 * np.pi)) * np.exp( - (bins - mu)**2 / (2 * sigma**2) )
plt.plot(gauss)

# %%
plt.hist??
