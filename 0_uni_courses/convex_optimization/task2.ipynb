# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Functions for bisection method
def bisection_method(fx, xmin_init, xmax_init, target):
    r""" Finding the closest solution, xopt, for the function f(x) = 0 by reducing the range between xmin and xmax 
    which corresponds to f(xmin) <= 0 and f(xmax) >= 0
    Parameters
    ----------
        fx: function
        xmin_init: int, float, np.ndarray
            Initial guess for xmin, make sure f(xmin) <= 0
        xmax_init: int, float, np.ndarray
            Initial guess for xmax, make sure f(xmax) >= 0
        target: float
            Operation breaks, when abs(f(xopt)) <= target
    Return
    ------
        xopt: float, np.ndarray
            Closest solution for f(x) = 0
    """
    xmin = xmin_init
    xmax = xmax_init
    print('Initial xmin = {}, xmax = {}'.format(xmin, xmax))
    print('fx(xmin) <= 0? {}'.format(fx(xmin) <= 0))
    print('fx(xmax) >= 0? {}'.format(fx(xmax) >= 0))
    if fx(xmin)*fx(xmax) > 0:
        raise AttributeError('Error in fx(xmin)*fx(xmax) > 0')
        
    # Initial error
    error = target + 1
    while np.abs(error) > target:
        xopt = (xmin + xmax)/2 # Calculate the middle point of xmax and xmin
        error = fx(xopt)
        print('Error = {}'.format(error))
        if np.abs(error) > target:
            # Swapping the either extreme with xopt to reduce the range
            if fx(xmin)* fx(xopt) > 0: 
                xmin = xopt
            else: 
                xmax = xopt
            print('Optimized xmin = {}, xmax = {}'.format(xmin, xmax))
        else:
            print('#======= Target reached!=======#')
            break
    return xopt


def flatten_npmat(vec_like):
    vec = vec_like.flatten()
    vec = np.array(vec.T)
    return np.reshape(vec, vec.shape[0])

# %%
# Parameter setting
M = 4 # number of TX elements
K = 3 # number of RX
lam = 0
eta = 10**-2 # Power limit for the interference 
sigma = 1.0
snr = 0 # dB
pmax = (sigma**2)* 10**(snr/10)
pmax
# Out:
# 1.0

# %%
# Channel
np.random.seed(0)
H = np.matrix(1/np.sqrt(2)*(np.random.random((M, K)) + 1j*np.random.random((M, K))))
# Mu: intial setting
Mu = 1*np.ones((K, K)) #np.random.random((K, K)) #
Mu = Mu - Mu.diagonal()*np.identity(K)
print(H)
# Out:
# [[0.38806975+0.40166816j 0.50571525+0.65449566j 0.42621807+0.05023008j]
#  [0.38529059+0.06160972j 0.29956918+0.01429657j 0.45671611+0.58875114j]
#  [0.30942088+0.55023992j 0.63057874+0.61519149j 0.68141247+0.69198767j]
#  [0.2711341 +0.56509044j 0.55983414+0.32631519j 0.37398518+0.55191747j]]

# %%
# Weight vectors
def weight_vector(h_k, mat):
    mat_inv = np.linalg.inv(mat)
    return np.dot(mat_inv, h_k)

def scaling_matrix(H, k, lam, method, mu_k = None):
    M = H.shape[0] # Number of TX elements
    K = H.shape[1] # Number of RX
    mat = np.matrix((0 + 0j)* np.ones((M, M)))
    mat += lam* np.identity(M)
    for j in range(K):
        if j != k:
            h_j = H[:, j]
            if method == 1:
                mat += np.dot(h_j, h_j.H)
            elif method == 2:
                mat += mu_k[j]* np.dot(h_j, h_j.H)
    return mat

# %%
k = 0
h_k = H[:, k]
lam = 1
# method 1
A0_1 = scaling_matrix(H, k, lam, 1, Mu[:, k])
v0_1 = weight_vector(h_k, A0_1)
print(A0_1)
print(v0_1)
# method 2
A0_2 = scaling_matrix(H, k, lam, 2, Mu[:, k])
v0_2 = weight_vector(h_k, A0_2)
print(A0_2)
print(v0_2)
# Out:
# [[1.86829739+0.j         0.38508742-0.03915875j 1.04672235-0.15911092j
#   0.68381064-0.01506545j]
#  [0.38508742+0.03915875j 1.64516359+0.j         0.91631766-0.09013684j
#   0.66812134-0.12163566j]
#  [1.04672235+0.15911092j 0.91631766+0.09013684j 2.71926   +0.j
#   1.19052409+0.02134747j]
#  [0.68381064+0.01506545j 0.66812134+0.12163566j 1.19052409-0.02134747j
#   1.86437368+0.j        ]]
# [[ 0.16563278+0.10914029j]
#  [ 0.174334  -0.13756325j]
#  [-0.01487277+0.08318266j]
#  [ 0.02265569+0.24636643j]]
# [[1.86829739+0.j         0.38508742-0.03915875j 1.04672235-0.15911092j
#   0.68381064-0.01506545j]
#  [0.38508742+0.03915875j 1.64516359+0.j         0.91631766-0.09013684j
#   0.66812134-0.12163566j]
#  [1.04672235+0.15911092j 0.91631766+0.09013684j 2.71926   +0.j
#   1.19052409+0.02134747j]
#  [0.68381064+0.01506545j 0.66812134+0.12163566j 1.19052409-0.02134747j
#   1.86437368+0.j        ]]
# [[ 0.16563278+0.10914029j]
#  [ 0.174334  -0.13756325j]
#  [-0.01487277+0.08318266j]
#  [ 0.02265569+0.24636643j]]

# %%
# Base to store the obtained results
V = np.matrix((0 + 0j)* np.ones((M, K)))
P = np.zeros((K, K))# Power
P_v = np.zeros(K)
sinr = np.zeros(K)
# Targets
target_pk = 0.0001*pmax/K
target_pj = 0.001*eta
# Initial setting
# lambda: larger lambda -> smaller norm(v_k)
lam_min = 10
lam_max = 10**(-8)#10**(-20)
mu_kj_min = 10**6 #-1.9
mu_kj_max = 10**(-6) #0
lam_opt = np.zeros(K)
Mu_opt = np.copy(Mu)

for k in range(Mu.shape[1]): 
    print('======================')
    print('RX No. {}'.format(k))
    print('======================')
    satisfied = False
    h_k = H[:, k]
    
    while satisfied == False:
        # Power constraint
        def flambda(lam):
            mat_k = scaling_matrix(H, k, lam, 2, Mu_opt[:, k])
            v_k = weight_vector(h_k, mat_k)
            power_k = np.linalg.norm(v_k)**2
            return power_k - pmax/K

        lam = bisection_method(flambda, lam_min, lam_max, target_pk) 
        lam_opt[k] = lam
        print('***lam_opt: {}'.format(lam_opt))

        # Interference constraint
        for j in range(Mu.shape[1]):
            if j != k:
                h_j = H[:, j]
                mu_k = np.copy(Mu_opt[:, k])
                mat_k = scaling_matrix(H, k, lam_opt[k], 2, mu_k)
                v_k = weight_vector(h_k, mat_k)
                interference = np.abs(np.dot(h_j.H, v_k))**2
                print('Interference: {}'.format(interference))
                
                if interference > eta:
                    def fmu(mu_kj):
                        mu_k[j] = mu_kj 
                        mat_k = scaling_matrix(H, k, lam_opt[k], 2, mu_k)
                        v_k = weight_vector(h_k, mat_k)
                        interference = np.abs(np.dot(h_j.H, v_k))**2
                        return interference - eta
                    
                    mu_kj_opt = bisection_method(fmu, mu_kj_min, mu_kj_max, target_pj) 
                    print('***mu_kj_opt : {}'.format(mu_kj_opt))
                    Mu_opt[j, k] = mu_kj_opt 

        # Check if the constraints are still fulfilled
        mat_k = scaling_matrix(H, k, lam_opt[k], 2, Mu_opt[:, k])
        v_k = weight_vector(h_k, mat_k)
        V[:, k] = v_k
        P_v[k] = np.linalg.norm(v_k)**2
        # Signal/interference power
        p_k = np.dot(H.H, v_k) # size = (K, 1)
        p_k = flatten_npmat(p_k) # size = K
        p_k = np.abs(p_k)**2
        P[:, k] = p_k # Store the results regarding the power
        p_int = p_k # Interference power
        p_int[k] = 0.0 # "Interference" of the desired signal = 0 
        print('Maximal interference power: {}'.format(max(p_int)))
        if np.abs(P_v[k] - pmax/K) > target_pk or max(p_int) - eta > target_pj:
            satisfied = False
            print('!!! Not yet satisfied !!!')
        else:
            satisfied = True
            print('!!! Satified :) !!!')
            p_all = np.sum(p_k)
            sinr[k] = P[k, k] / (p_all - P[k, k] + sigma**2)
           
        
print('Mu_opt: {}'.format(Mu_opt))
print('lam_opt: {}'.format(lam_opt))
# Out:
# ======================
# RX No. 0
# ======================
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.31368563648519254
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.2857783325289466
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = -0.21819709964131268
# Optimized xmin = 1.25000000875, xmax = 1e-08
# Error = -0.012607117701413928
# Optimized xmin = 0.625000009375, xmax = 1e-08
# Error = 0.7244212824380474
# Optimized xmin = 0.625000009375, xmax = 0.3125000096875
# Error = 0.1836677109161184
# Optimized xmin = 0.625000009375, xmax = 0.46875000953125
# Error = 0.06554836372496847
# Optimized xmin = 0.625000009375, xmax = 0.546875009453125
# Error = 0.02276015267215259
# Optimized xmin = 0.625000009375, xmax = 0.5859375094140624
# Error = 0.004265377907390955
# Optimized xmin = 0.625000009375, xmax = 0.6054687593945312
# Error = -0.004361081343531581
# Optimized xmin = 0.6152343843847656, xmax = 0.6054687593945312
# Error = -9.689854345945603e-05
# Optimized xmin = 0.6103515718896484, xmax = 0.6054687593945312
# Error = 0.002071784723116865
# Optimized xmin = 0.6103515718896484, xmax = 0.6079101656420898
# Error = 0.000984353806207483
# Optimized xmin = 0.6103515718896484, xmax = 0.6091308687658691
# Error = 0.00044295834098972975
# Optimized xmin = 0.6103515718896484, xmax = 0.6097412203277588
# Error = 0.00017283795334327445
# Optimized xmin = 0.6103515718896484, xmax = 0.6100463961087036
# Error = 3.7921765631221405e-05
# Optimized xmin = 0.6103515718896484, xmax = 0.6101989839991759
# Error = -2.9500367867640875e-05
# #======= Target reached!=======#
# ***lam_opt: [0.61027528 0.         0.        ]
# Interference: [[0.16073303]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.00999997]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999989]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999956]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999823]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00999296]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.00997197]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.009889]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00956481]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.00832657]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[-0.00380009]]
# Optimized xmin = 7.629395531242371, xmax = 1e-06
# Error = [[0.0114527]]
# Optimized xmin = 7.629395531242371, xmax = 3.8146982656211854
# Error = [[0.00048973]]
# Optimized xmin = 7.629395531242371, xmax = 5.722046898431778
# Error = [[-0.00207334]]
# Optimized xmin = 6.675721214837074, xmax = 5.722046898431778
# Error = [[-0.00092601]]
# Optimized xmin = 6.198884056634426, xmax = 5.722046898431778
# Error = [[-0.00025659]]
# Optimized xmin = 5.960465477533102, xmax = 5.722046898431778
# Error = [[0.00010624]]
# Optimized xmin = 5.960465477533102, xmax = 5.84125618798244
# Error = [[-7.76631034e-05]]
# Optimized xmin = 5.900860832757771, xmax = 5.84125618798244
# Error = [[1.36555782e-05]]
# Optimized xmin = 5.900860832757771, xmax = 5.871058510370105
# Error = [[-3.21606233e-05]]
# Optimized xmin = 5.885959671563938, xmax = 5.871058510370105
# Error = [[-9.29191764e-06]]
# #======= Target reached!=======#
# ***mu_kj_opt : 5.878509090967022
# Interference: [[0.02821096]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999998]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999991]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999964]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00999858]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.00999434]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.00997764]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00991265]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.00966656]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[-0.00878146]]
# Optimized xmin = 7.629395531242371, xmax = 1e-06
# Error = [[-0.00588497]]
# Optimized xmin = 3.8146982656211854, xmax = 1e-06
# Error = [[0.00218343]]
# Optimized xmin = 3.8146982656211854, xmax = 1.9073496328105928
# Error = [[-0.00341619]]
# Optimized xmin = 2.8610239492158893, xmax = 1.9073496328105928
# Error = [[-0.00125254]]
# Optimized xmin = 2.3841867910132413, xmax = 1.9073496328105928
# Error = [[0.00025297]]
# Optimized xmin = 2.3841867910132413, xmax = 2.145768211911917
# Error = [[-0.00054457]]
# Optimized xmin = 2.264977501462579, xmax = 2.145768211911917
# Error = [[-0.00015791]]
# Optimized xmin = 2.205372856687248, xmax = 2.145768211911917
# Error = [[4.43789147e-05]]
# Optimized xmin = 2.205372856687248, xmax = 2.1755705342995824
# Error = [[-5.75359233e-05]]
# Optimized xmin = 2.1904716954934154, xmax = 2.1755705342995824
# Error = [[-6.77338274e-06]]
# #======= Target reached!=======#
# ***mu_kj_opt : 2.1830211148964986
# Maximal interference power: 0.009993226617261371
# !!! Not yet satisfied !!!
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.3266742324464179
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.314682052816591
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = -0.2700638596689378
# Optimized xmin = 1.25000000875, xmax = 1e-08
# Error = -0.09459662678315509
# Optimized xmin = 0.625000009375, xmax = 1e-08
# Error = 0.6045559786307666
# Optimized xmin = 0.625000009375, xmax = 0.3125000096875
# Error = 0.08679571440226619
# Optimized xmin = 0.625000009375, xmax = 0.46875000953125
# Error = -0.023177501006297063
# Optimized xmin = 0.546875009453125, xmax = 0.46875000953125
# Error = 0.025484354484088256
# Optimized xmin = 0.546875009453125, xmax = 0.5078125094921875
# Error = -0.00019595381170023352
# Optimized xmin = 0.5273437594726562, xmax = 0.5078125094921875
# Error = 0.012281287371568084
# Optimized xmin = 0.5273437594726562, xmax = 0.5175781344824218
# Error = 0.005955321332046071
# Optimized xmin = 0.5273437594726562, xmax = 0.522460946977539
# Error = 0.0028582530801647965
# Optimized xmin = 0.5273437594726562, xmax = 0.5249023532250976
# Error = 0.0013258416462470501
# Optimized xmin = 0.5273437594726562, xmax = 0.5261230563488769
# Error = 0.0005636230676041021
# Optimized xmin = 0.5273437594726562, xmax = 0.5267334079107666
# Error = 0.00018350518005849636
# Optimized xmin = 0.5273437594726562, xmax = 0.5270385836917114
# Error = -6.306582470916311e-06
# #======= Target reached!=======#
# ***lam_opt: [0.52719117 0.         0.        ]
# Interference: [[0.00880991]]
# Interference: [[0.01020031]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999998]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999991]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999966]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00999864]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.00999458]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.00997855]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00991596]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.00967735]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[-0.00880813]]
# Optimized xmin = 7.629395531242371, xmax = 1e-06
# Error = [[-0.00589761]]
# Optimized xmin = 3.8146982656211854, xmax = 1e-06
# Error = [[0.00252213]]
# Optimized xmin = 3.8146982656211854, xmax = 1.9073496328105928
# Error = [[-0.00336279]]
# Optimized xmin = 2.8610239492158893, xmax = 1.9073496328105928
# Error = [[-0.00110923]]
# Optimized xmin = 2.3841867910132413, xmax = 1.9073496328105928
# Error = [[0.00047439]]
# Optimized xmin = 2.3841867910132413, xmax = 2.145768211911917
# Error = [[-0.00036604]]
# Optimized xmin = 2.264977501462579, xmax = 2.145768211911917
# Error = [[4.10000167e-05]]
# Optimized xmin = 2.264977501462579, xmax = 2.205372856687248
# Error = [[-0.00016568]]
# Optimized xmin = 2.2351751790749135, xmax = 2.205372856687248
# Error = [[-6.31447758e-05]]
# Optimized xmin = 2.2202740178810805, xmax = 2.205372856687248
# Error = [[-1.1275971e-05]]
# Optimized xmin = 2.212823437284164, xmax = 2.205372856687248
# Error = [[1.48108592e-05]]
# Optimized xmin = 2.212823437284164, xmax = 2.2090981469857063
# Error = [[1.75468654e-06]]
# #======= Target reached!=======#
# ***mu_kj_opt : 2.2109607921349355
# Maximal interference power: 0.010001754686540475
# !!! Not yet satisfied !!!
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.3266902111769087
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.3147097747570615
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = -0.27010784668446436
# Optimized xmin = 1.25000000875, xmax = 1e-08
# Error = -0.09466150381095514
# Optimized xmin = 0.625000009375, xmax = 1e-08
# Error = 0.6044697253232316
# Optimized xmin = 0.625000009375, xmax = 0.3125000096875
# Error = 0.08672169206744523
# Optimized xmin = 0.625000009375, xmax = 0.46875000953125
# Error = -0.023246638108921358
# Optimized xmin = 0.546875009453125, xmax = 0.46875000953125
# Error = 0.02541286065863363
# Optimized xmin = 0.546875009453125, xmax = 0.5078125094921875
# Error = -0.0002662488443629929
# Optimized xmin = 0.5273437594726562, xmax = 0.5078125094921875
# Error = 0.012210398175645676
# Optimized xmin = 0.5273437594726562, xmax = 0.5175781344824218
# Error = 0.005884730510078651
# Optimized xmin = 0.5273437594726562, xmax = 0.522460946977539
# Error = 0.0027878104739626486
# Optimized xmin = 0.5273437594726562, xmax = 0.5249023532250976
# Error = 0.0012554729068488535
# Optimized xmin = 0.5273437594726562, xmax = 0.5261230563488769
# Error = 0.0004932912015516155
# Optimized xmin = 0.5273437594726562, xmax = 0.5267334079107666
# Error = 0.00011319173569152019
# Optimized xmin = 0.5273437594726562, xmax = 0.5270385836917114
# Error = -7.661081973830974e-05
# Optimized xmin = 0.5271911715821838, xmax = 0.5270385836917114
# Error = 1.8269879720700377e-05
# #======= Target reached!=======#
# ***lam_opt: [0.52711488 0.         0.        ]
# Interference: [[0.00879448]]
# Interference: [[0.01000194]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999998]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999991]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999966]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00999864]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.00999458]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.00997855]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00991596]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.00967736]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[-0.00880815]]
# Optimized xmin = 7.629395531242371, xmax = 1e-06
# Error = [[-0.00589763]]
# Optimized xmin = 3.8146982656211854, xmax = 1e-06
# Error = [[0.00252245]]
# Optimized xmin = 3.8146982656211854, xmax = 1.9073496328105928
# Error = [[-0.00336274]]
# Optimized xmin = 2.8610239492158893, xmax = 1.9073496328105928
# Error = [[-0.0011091]]
# Optimized xmin = 2.3841867910132413, xmax = 1.9073496328105928
# Error = [[0.0004746]]
# Optimized xmin = 2.3841867910132413, xmax = 2.145768211911917
# Error = [[-0.00036587]]
# Optimized xmin = 2.264977501462579, xmax = 2.145768211911917
# Error = [[4.11890487e-05]]
# Optimized xmin = 2.264977501462579, xmax = 2.205372856687248
# Error = [[-0.0001655]]
# Optimized xmin = 2.2351751790749135, xmax = 2.205372856687248
# Error = [[-6.29608545e-05]]
# Optimized xmin = 2.2202740178810805, xmax = 2.205372856687248
# Error = [[-1.10895105e-05]]
# Optimized xmin = 2.212823437284164, xmax = 2.205372856687248
# Error = [[1.49986014e-05]]
# Optimized xmin = 2.212823437284164, xmax = 2.2090981469857063
# Error = [[1.94178687e-06]]
# #======= Target reached!=======#
# ***mu_kj_opt : 2.2109607921349355
# Maximal interference power: 0.010001941786866177
# !!! Satified :) !!!
# ======================
# RX No. 1
# ======================
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.29362134367801945
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.2213063662663186
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = -0.015361002704020243
# Optimized xmin = 1.25000000875, xmax = 1e-08
# Error = 0.6264699439849835
# Optimized xmin = 1.25000000875, xmax = 0.625000009375
# Error = 0.16566085587323925
# Optimized xmin = 1.25000000875, xmax = 0.9375000090625001
# Error = 0.058030301702182596
# Optimized xmin = 1.25000000875, xmax = 1.09375000890625
# Error = 0.01809746047553923
# Optimized xmin = 1.25000000875, xmax = 1.171875008828125
# Error = 0.0006550193287727102
# Optimized xmin = 1.25000000875, xmax = 1.2109375087890624
# Error = -0.007520847527669128
# Optimized xmin = 1.2304687587695313, xmax = 1.2109375087890624
# Error = -0.003476122314514496
# Optimized xmin = 1.2207031337792968, xmax = 1.2109375087890624
# Error = -0.0014215142427554395
# Optimized xmin = 1.2158203212841796, xmax = 1.2109375087890624
# Error = -0.00038600856539106054
# Optimized xmin = 1.213378915036621, xmax = 1.2109375087890624
# Error = 0.00013381253074468136
# Optimized xmin = 1.213378915036621, xmax = 1.2121582119128416
# Error = -0.00012627090737404867
# Optimized xmin = 1.2127685634747314, xmax = 1.2121582119128416
# Error = 3.7275488968813164e-06
# #======= Target reached!=======#
# ***lam_opt: [0.52711488 1.21246339 0.        ]
# Interference: [[0.17931272]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.00999998]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.0099999]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999962]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999848]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999396]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00997601]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.00990547]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.0096329]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00861413]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.0050384]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[0.00616957]]
# Optimized xmin = 15.258790062484742, xmax = 7.629395531242371
# Error = [[-0.0017811]]
# Optimized xmin = 11.444092796863556, xmax = 7.629395531242371
# Error = [[0.00120432]]
# Optimized xmin = 11.444092796863556, xmax = 9.536744164052964
# Error = [[-0.00046115]]
# Optimized xmin = 10.49041848045826, xmax = 9.536744164052964
# Error = [[0.00032139]]
# Optimized xmin = 10.49041848045826, xmax = 10.013581322255611
# Error = [[-8.14450492e-05]]
# Optimized xmin = 10.251999901356935, xmax = 10.013581322255611
# Error = [[0.00011696]]
# Optimized xmin = 10.251999901356935, xmax = 10.132790611806273
# Error = [[1.70230446e-05]]
# Optimized xmin = 10.251999901356935, xmax = 10.192395256581605
# Error = [[-3.23933899e-05]]
# Optimized xmin = 10.22219757896927, xmax = 10.192395256581605
# Error = [[-7.73099508e-06]]
# #======= Target reached!=======#
# ***mu_kj_opt : 10.207296417775439
# Interference: [[0.00466237]]
# Maximal interference power: 0.009992269004919683
# !!! Not yet satisfied !!!
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.319854395997341
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.29226087192678596
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = -0.18901506515852276
# Optimized xmin = 1.25000000875, xmax = 1e-08
# Error = 0.21083493372515733
# Optimized xmin = 1.25000000875, xmax = 0.625000009375
# Error = -0.08429573867262227
# Optimized xmin = 0.9375000090625001, xmax = 0.625000009375
# Error = 0.020067931030766983
# Optimized xmin = 0.9375000090625001, xmax = 0.78125000921875
# Error = -0.039122944856116226
# Optimized xmin = 0.859375009140625, xmax = 0.78125000921875
# Error = -0.011614498245671567
# Optimized xmin = 0.8203125091796875, xmax = 0.78125000921875
# Error = 0.0036541405006826344
# Optimized xmin = 0.8203125091796875, xmax = 0.8007812591992187
# Error = -0.004116492567732222
# Optimized xmin = 0.8105468841894531, xmax = 0.8007812591992187
# Error = -0.00026607606281409124
# Optimized xmin = 0.805664071694336, xmax = 0.8007812591992187
# Error = 0.0016852017874262049
# Optimized xmin = 0.805664071694336, xmax = 0.8032226654467773
# Error = 0.000707368556909227
# Optimized xmin = 0.805664071694336, xmax = 0.8044433685705566
# Error = 0.0002200993225298098
# Optimized xmin = 0.805664071694336, xmax = 0.8050537201324464
# Error = -2.3124895474180285e-05
# #======= Target reached!=======#
# ***lam_opt: [0.52711488 0.8053589  0.        ]
# Interference: [[0.01088683]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.00999998]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.0099999]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999962]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999847]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999388]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00997566]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.00990374]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.00962357]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00855973]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.0047138]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[0.00798801]]
# Optimized xmin = 15.258790062484742, xmax = 7.629395531242371
# Error = [[-0.00110844]]
# Optimized xmin = 11.444092796863556, xmax = 7.629395531242371
# Error = [[0.00226236]]
# Optimized xmin = 11.444092796863556, xmax = 9.536744164052964
# Error = [[0.00037468]]
# Optimized xmin = 11.444092796863556, xmax = 10.49041848045826
# Error = [[-0.00040973]]
# Optimized xmin = 10.967255638660909, xmax = 10.49041848045826
# Error = [[-2.90870931e-05]]
# Optimized xmin = 10.728837059559584, xmax = 10.49041848045826
# Error = [[0.00016979]]
# Optimized xmin = 10.728837059559584, xmax = 10.609627770008922
# Error = [[6.96157484e-05]]
# Optimized xmin = 10.728837059559584, xmax = 10.669232414784254
# Error = [[2.00820291e-05]]
# Optimized xmin = 10.728837059559584, xmax = 10.69903473717192
# Error = [[-4.54788251e-06]]
# #======= Target reached!=======#
# ***mu_kj_opt : 10.71393589836575
# Interference: [[0.00379106]]
# Maximal interference power: 0.009995452117487326
# !!! Not yet satisfied !!!
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.3201706954169415
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.29280071107617645
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = -0.18989956100300495
# Optimized xmin = 1.25000000875, xmax = 1e-08
# Error = 0.20933545337008247
# Optimized xmin = 1.25000000875, xmax = 0.625000009375
# Error = -0.08539363478385409
# Optimized xmin = 0.9375000090625001, xmax = 0.625000009375
# Error = 0.018805079864296914
# Optimized xmin = 0.9375000090625001, xmax = 0.78125000921875
# Error = -0.04029648281328557
# Optimized xmin = 0.859375009140625, xmax = 0.78125000921875
# Error = -0.012830770130985936
# Optimized xmin = 0.8203125091796875, xmax = 0.78125000921875
# Error = 0.0024150901105702283
# Optimized xmin = 0.8203125091796875, xmax = 0.8007812591992187
# Error = -0.005344029917771553
# Optimized xmin = 0.8105468841894531, xmax = 0.8007812591992187
# Error = -0.0014993384987976865
# Optimized xmin = 0.805664071694336, xmax = 0.8007812591992187
# Error = 0.0004490532948563386
# Optimized xmin = 0.805664071694336, xmax = 0.8032226654467773
# Error = -0.0005273349350404799
# Optimized xmin = 0.8044433685705566, xmax = 0.8032226654467773
# Error = -3.969055734187599e-05
# Optimized xmin = 0.8038330170086669, xmax = 0.8032226654467773
# Error = 0.0002045437270118411
# Optimized xmin = 0.8038330170086669, xmax = 0.8035278412277221
# Error = 8.23922003586608e-05
# Optimized xmin = 0.8038330170086669, xmax = 0.8036804291181945
# Error = 2.134222863164892e-05
# #======= Target reached!=======#
# ***lam_opt: [0.52711488 0.80375672 0.        ]
# Interference: [[0.00999913]]
# Interference: [[0.00378955]]
# Maximal interference power: 0.009999125242530533
# !!! Satified :) !!!
# ======================
# RX No. 2
# ======================
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.2855853554501275
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.18611565202028932
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = 0.1408186422775759
# Optimized xmin = 2.5000000075, xmax = 1.25000000875
# Error = -0.09636489266982168
# Optimized xmin = 1.8750000081250002, xmax = 1.25000000875
# Error = -0.010827996561345699
# Optimized xmin = 1.5625000084375, xmax = 1.25000000875
# Error = 0.0530888352353866
# Optimized xmin = 1.5625000084375, xmax = 1.4062500085937502
# Error = 0.018756953246564456
# Optimized xmin = 1.5625000084375, xmax = 1.484375008515625
# Error = 0.0034300387305379876
# Optimized xmin = 1.5625000084375, xmax = 1.5234375084765626
# Error = -0.0038260224564054535
# Optimized xmin = 1.5429687584570313, xmax = 1.5234375084765626
# Error = -0.00023054135218225635
# Optimized xmin = 1.533203133466797, xmax = 1.5234375084765626
# Error = 0.0015915100208823696
# Optimized xmin = 1.533203133466797, xmax = 1.5283203209716798
# Error = 0.000678437453718761
# Optimized xmin = 1.533203133466797, xmax = 1.5307617272192384
# Error = 0.00022343791793399959
# Optimized xmin = 1.533203133466797, xmax = 1.5319824303430178
# Error = -3.679052598626331e-06
# #======= Target reached!=======#
# ***lam_opt: [0.52711488 0.80375672 1.53259278]
# Interference: [[0.11059491]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.00999998]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.00999991]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999966]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999862]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999453]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00997832]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.00991498]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.00967293]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00878724]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.00579744]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[0.00296963]]
# Optimized xmin = 15.258790062484742, xmax = 7.629395531242371
# Error = [[-0.00317353]]
# Optimized xmin = 11.444092796863556, xmax = 7.629395531242371
# Error = [[-0.00082874]]
# Optimized xmin = 9.536744164052964, xmax = 7.629395531242371
# Error = [[0.00082487]]
# Optimized xmin = 9.536744164052964, xmax = 8.583069847647668
# Error = [[-5.32737795e-05]]
# Optimized xmin = 9.059907005850317, xmax = 8.583069847647668
# Error = [[0.00037187]]
# Optimized xmin = 9.059907005850317, xmax = 8.821488426748992
# Error = [[0.00015596]]
# Optimized xmin = 9.059907005850317, xmax = 8.940697716299654
# Error = [[5.05280493e-05]]
# Optimized xmin = 9.059907005850317, xmax = 9.000302361074986
# Error = [[-1.57492162e-06]]
# #======= Target reached!=======#
# ***mu_kj_opt : 9.030104683462651
# Interference: [[0.00836694]]
# Maximal interference power: 0.009998425078383577
# !!! Not yet satisfied !!!
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.3067378747444674
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.24005963556012283
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = 0.01916439366989675
# Optimized xmin = 2.5000000075, xmax = 1.25000000875
# Error = -0.17236868259396937
# Optimized xmin = 1.8750000081250002, xmax = 1.25000000875
# Error = -0.10473604530727532
# Optimized xmin = 1.5625000084375, xmax = 1.25000000875
# Error = -0.05299250187453003
# Optimized xmin = 1.4062500085937502, xmax = 1.25000000875
# Error = -0.020070571404433246
# Optimized xmin = 1.3281250086718752, xmax = 1.25000000875
# Error = -0.001338056978419655
# Optimized xmin = 1.2890625087109377, xmax = 1.25000000875
# Error = 0.008678329012504316
# Optimized xmin = 1.2890625087109377, xmax = 1.2695312587304688
# Error = 0.0036132066517809425
# Optimized xmin = 1.2890625087109377, xmax = 1.2792968837207033
# Error = 0.001123557694217625
# Optimized xmin = 1.2890625087109377, xmax = 1.2841796962158205
# Error = -0.00011072747220997048
# Optimized xmin = 1.2866211024633791, xmax = 1.2841796962158205
# Error = 0.0005055423660827452
# Optimized xmin = 1.2866211024633791, xmax = 1.2854003993395997
# Error = 0.00019718967284410027
# Optimized xmin = 1.2866211024633791, xmax = 1.2860107509014895
# Error = 4.3176708204806236e-05
# Optimized xmin = 1.2866211024633791, xmax = 1.2863159266824344
# Error = -3.378897361083766e-05
# Optimized xmin = 1.2864685145729067, xmax = 1.2863159266824344
# Error = 4.690468592805086e-06
# #======= Target reached!=======#
# ***lam_opt: [0.52711488 0.80375672 1.28639222]
# Interference: [[0.01046909]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.00999998]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.00999991]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999965]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999861]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999448]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00997814]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.00991411]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.00966843]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00876244]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.00566053]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[0.00365553]]
# Optimized xmin = 15.258790062484742, xmax = 7.629395531242371
# Error = [[-0.00290131]]
# Optimized xmin = 11.444092796863556, xmax = 7.629395531242371
# Error = [[-0.00041313]]
# Optimized xmin = 9.536744164052964, xmax = 7.629395531242371
# Error = [[0.00135273]]
# Optimized xmin = 9.536744164052964, xmax = 8.583069847647668
# Error = [[0.00041389]]
# Optimized xmin = 9.536744164052964, xmax = 9.059907005850317
# Error = [[-1.2448718e-05]]
# Optimized xmin = 9.298325584951641, xmax = 9.059907005850317
# Error = [[0.00019738]]
# Optimized xmin = 9.298325584951641, xmax = 9.179116295400979
# Error = [[9.16472864e-05]]
# Optimized xmin = 9.298325584951641, xmax = 9.23872094017631
# Error = [[3.93969101e-05]]
# Optimized xmin = 9.298325584951641, xmax = 9.268523262563976
# Error = [[1.34237644e-05]]
# Optimized xmin = 9.298325584951641, xmax = 9.283424423757808
# Error = [[4.74972839e-07]]
# #======= Target reached!=======#
# ***mu_kj_opt : 9.290875004354724
# Interference: [[0.00784067]]
# Maximal interference power: 0.010000474972839091
# !!! Not yet satisfied !!!
# Initial xmin = 10, xmax = 1e-08
# fx(xmin) <= 0? True
# fx(xmax) >= 0? True
# Error = -0.30691970516798195
# Optimized xmin = 5.000000005, xmax = 1e-08
# Error = -0.24037447922741084
# Optimized xmin = 2.5000000075, xmax = 1e-08
# Error = 0.018633191956002937
# Optimized xmin = 2.5000000075, xmax = 1.25000000875
# Error = -0.17275626263971192
# Optimized xmin = 1.8750000081250002, xmax = 1.25000000875
# Error = -0.1051803394584733
# Optimized xmin = 1.5625000084375, xmax = 1.25000000875
# Error = -0.05347498397342931
# Optimized xmin = 1.4062500085937502, xmax = 1.25000000875
# Error = -0.0205758215709968
# Optimized xmin = 1.3281250086718752, xmax = 1.25000000875
# Error = -0.0018558422220130155
# Optimized xmin = 1.2890625087109377, xmax = 1.25000000875
# Error = 0.008153951707359386
# Optimized xmin = 1.2890625087109377, xmax = 1.2695312587304688
# Error = 0.0030921536385137283
# Optimized xmin = 1.2890625087109377, xmax = 1.2792968837207033
# Error = 0.0006041455362132409
# Optimized xmin = 1.2890625087109377, xmax = 1.2841796962158205
# Error = -0.000629324442080248
# Optimized xmin = 1.2866211024633791, xmax = 1.2841796962158205
# Error = -1.3461763671118732e-05
# #======= Target reached!=======#
# ***lam_opt: [0.52711488 0.80375672 1.2854004 ]
# Interference: [[0.01000239]]
# Initial xmin = 1000000, xmax = 1e-06
# fx(xmin) <= 0? [[ True]]
# fx(xmax) >= 0? [[ True]]
# Error = [[-0.01]]
# Optimized xmin = 500000.0000005, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 250000.00000075, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 125000.000000875, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 62500.0000009375, xmax = 1e-06
# Error = [[-0.01]]
# Optimized xmin = 31250.00000096875, xmax = 1e-06
# Error = [[-0.00999999]]
# Optimized xmin = 15625.000000984375, xmax = 1e-06
# Error = [[-0.00999998]]
# Optimized xmin = 7812.500000992188, xmax = 1e-06
# Error = [[-0.00999991]]
# Optimized xmin = 3906.250000996094, xmax = 1e-06
# Error = [[-0.00999965]]
# Optimized xmin = 1953.125000998047, xmax = 1e-06
# Error = [[-0.00999861]]
# Optimized xmin = 976.5625009990235, xmax = 1e-06
# Error = [[-0.00999448]]
# Optimized xmin = 488.28125099951177, xmax = 1e-06
# Error = [[-0.00997814]]
# Optimized xmin = 244.14062599975588, xmax = 1e-06
# Error = [[-0.0099141]]
# Optimized xmin = 122.07031349987794, xmax = 1e-06
# Error = [[-0.00966841]]
# Optimized xmin = 61.03515724993897, xmax = 1e-06
# Error = [[-0.00876234]]
# Optimized xmin = 30.517579124969483, xmax = 1e-06
# Error = [[-0.00565994]]
# Optimized xmin = 15.258790062484742, xmax = 1e-06
# Error = [[0.00365851]]
# Optimized xmin = 15.258790062484742, xmax = 7.629395531242371
# Error = [[-0.00290014]]
# Optimized xmin = 11.444092796863556, xmax = 7.629395531242371
# Error = [[-0.00041133]]
# Optimized xmin = 9.536744164052964, xmax = 7.629395531242371
# Error = [[0.00135502]]
# Optimized xmin = 9.536744164052964, xmax = 8.583069847647668
# Error = [[0.00041591]]
# Optimized xmin = 9.536744164052964, xmax = 9.059907005850317
# Error = [[-1.05420431e-05]]
# Optimized xmin = 9.298325584951641, xmax = 9.059907005850317
# Error = [[0.00019934]]
# Optimized xmin = 9.298325584951641, xmax = 9.179116295400979
# Error = [[9.35822156e-05]]
# Optimized xmin = 9.298325584951641, xmax = 9.23872094017631
# Error = [[4.1317641e-05]]
# Optimized xmin = 9.298325584951641, xmax = 9.268523262563976
# Error = [[1.53374496e-05]]
# Optimized xmin = 9.298325584951641, xmax = 9.283424423757808
# Error = [[2.38514851e-06]]
# #======= Target reached!=======#
# ***mu_kj_opt : 9.290875004354724
# Interference: [[0.00784]]
# Maximal interference power: 0.010002385148506593
# !!! Satified :) !!!
# Mu_opt: [[ 0.         10.7139359   9.290875  ]
#  [ 5.87850909  0.          1.        ]
#  [ 2.21096079  1.          0.        ]]
# lam_opt: [0.52711488 0.80375672 1.2854004 ]

# %%
print('Mu_opt: {}'.format(Mu_opt))
print('lam_opt: {}'.format(lam_opt))
# Out:
# Mu_opt: [[ 0.         10.7139359   9.290875  ]
#  [ 5.87850909  0.          1.        ]
#  [ 2.21096079  1.          0.        ]]
# lam_opt: [0.52711488 0.80375672 1.2854004 ]

# %%
print('Power: \n {}'.format(P))
print('SINR: {}dB'.format(10*(np.log10(sinr))))
# Out:
# Power:
#  [[0.06226368 0.00999913 0.01000239]
#  [0.00879448 0.14353156 0.00784   ]
#  [0.01000194 0.00378955 0.28007424]]
# SINR: [-11.86465061  -7.82700165  -4.2064674 ]dB

# %%
print(P_v)
# Out:
# [0.3333516  0.33335468 0.33331987]
